# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
air = pd.read_csv("C:\\Users\\Dell\\DataScience\\Kaggle Files\\Creditcard_fraud-master\\air.csv", parse_dates=[['Date', 'Time']])
air.head()
# Out:
#             Date_Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# 0 2004-03-10 18:00:00     2.6         1360       150      11.9           1046
# 1 2004-03-10 19:00:00     2.0         1292       112       9.4            955
# 2 2004-03-10 20:00:00     2.2         1402        88       9.0            939
# 3 2004-03-10 21:00:00     2.2         1376        80       9.2            948
# 4 2004-03-10 22:00:00     1.6         1272        51       6.5            836
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0      166          1056      113          1692         1268  13.6  48.9
# 1      103          1174       92          1559          972  13.3  47.7
# 2      131          1140      114          1555         1074  11.9  54.0
# 3      172          1092      122          1584         1203  11.0  60.0
# 4      131          1205      116          1490         1110  11.2  59.6
#
#        AH
# 0  0.7578
# 1  0.7255
# 2  0.7502
# 3  0.7867
# ...

# %%
airD = pd.DataFrame(air)
airD
# Out:
#                Date_Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0    2004-03-10 18:00:00     2.6         1360       150      11.9
# 1    2004-03-10 19:00:00     2.0         1292       112       9.4
# 2    2004-03-10 20:00:00     2.2         1402        88       9.0
# 3    2004-03-10 21:00:00     2.2         1376        80       9.2
# 4    2004-03-10 22:00:00     1.6         1272        51       6.5
# 5    2004-03-10 23:00:00     1.2         1197        38       4.7
# 6    2004-03-11 00:00:00     1.2         1185        31       3.6
# 7    2004-03-11 01:00:00     1.0         1136        31       3.3
# 8    2004-03-11 02:00:00     0.9         1094        24       2.3
# 9    2004-03-11 03:00:00     0.6         1010        19       1.7
# 10   2004-03-11 04:00:00  -200.0         1011        14       1.3
# 11   2004-03-11 05:00:00     0.7         1066         8       1.1
# 12   2004-03-11 06:00:00     0.7         1052        16       1.6
# ...

# %%
airD.isnull().sum()
# Out:
# Date_Time        0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %%
airD.dtypes
# Out:
# Date_Time        datetime64[ns]
# CO(GT)                  float64
# PT08.S1(CO)               int64
# NMHC(GT)                  int64
# C6H6(GT)                float64
# PT08.S2(NMHC)             int64
# NOx(GT)                   int64
# PT08.S3(NOx)              int64
# NO2(GT)                   int64
# PT08.S4(NO2)              int64
# PT08.S5(O3)               int64
# T                       float64
# RH                      float64
# AH                      float64
# dtype: object

# %%
pd.options.mode.chained_assignment = None  
cols = airD.columns
cnt = 0
for j in cols:
    for i in range(0,len(airD)):
        if(airD[j][i]==-200):
            airD[j][i] = airD[j][i-1]
print("Done!")
# Out:
# Done!

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen
#from statsmodels.tsa.vector_ar.vecm import JohansenTestResult
#from johansen import coint_johansen
johan_test_temp = airD.drop(['Date_Time'], axis=1)
coint_johansen(johan_test_temp,0,1).eig

#Eigen values for the lag polynomial must be less than 1, for the data to be multivariate time series stationary: Johansen Test, similar to Dickey Fuller Test.
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\statsmodels\tsa\vector_ar\vecm.py:608: HypothesisTestWarning: Critical values are only available for time series with 12 variables at most.
#   category=HypothesisTestWarning)
# array([0.19849152, 0.15914057, 0.12321066, 0.10731769, 0.09540444,
#        0.08325317, 0.06642627, 0.05803392, 0.04035113, 0.03390943,
#        0.02782613, 0.00953236, 0.00202889])

# %%
airD['Date_Time'] = airD['Date_Time'].values.astype(float)

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen
df = airD.drop(['Date_Time'], axis=1)
def cointegration_test(df, alpha=0.05): 
    out = coint_johansen(df,-1,1)
    d = {'0.90':0, '0.95':1, '0.99':2}
    traces = out.lr1
    cvts = out.cvt[:, d[str(1-alpha)]]
    def adjust(val, length= 6): return str(val).ljust(length)

    # Summary
    print('Name   ::  Test Stat > C(95%)    =>   Signif  \n', '--'*20)
    for col, trace, cvt in zip(df.columns, traces, cvts):
        print(adjust(col), ':: ', adjust(round(trace,2), 9), ">", adjust(cvt, 8), ' =>  ' , trace > cvt)

cointegration_test(df.astype(float))
# Out:
# Name   ::  Test Stat > C(95%)    =>   Signif
#  ----------------------------------------
# CO(GT) ::  9113.24   > nan       =>   False
# PT08.S1(CO) ::  7336.47   > 311.1288  =>   True
# NMHC(GT) ::  5780.43   > 263.2603  =>   True
# C6H6(GT) ::  4627.49   > 219.4051  =>   True
# PT08.S2(NMHC) ::  3566.39   > 179.5199  =>   True
# NOx(GT) ::  2642.34   > 143.6691  =>   True
# PT08.S3(NOx) ::  1922.53   > 111.7797  =>   True
# NO2(GT) ::  1306.38   > 83.9383   =>   True
# PT08.S4(NO2) ::  750.51    > 60.0627   =>   True
# PT08.S5(O3) ::  423.38    > 40.1749   =>   True
# T      ::  135.39    > 24.2761   =>   True
# RH     ::  23.99     > 12.3212   =>   True
# AH     ::  0.66      > 4.1296    =>   False
# C:\Users\Dell\Anaconda3\lib\site-packages\statsmodels\tsa\vector_ar\vecm.py:608: HypothesisTestWarning: Critical values are only available for time series with 12 variables at most.
#   category=HypothesisTestWarning)

# %%
train = df[:int(0.8*(len(df)))]
valid = df[int(0.8*(len(df))):]
from statsmodels.tsa.vector_ar.var_model import VAR

model = VAR(endog=train)
model_fit = model.fit()
prediction = model_fit.forecast(model_fit.y, steps=len(valid))
print(prediction)
# Out:
# [[8.87831181e-01 8.41930040e+02 2.71627237e+02 ... 1.05475985e+01
#   3.49086438e+01 4.37327493e-01]
#  [9.91857261e-01 8.66300135e+02 2.69296720e+02 ... 9.82637273e+00
#   3.74495946e+01 4.42716879e-01]
#  [1.10418099e+00 8.90877509e+02 2.67701932e+02 ... 9.21409050e+00
#   3.96788583e+01 4.47482162e-01]
#  ...
#  [2.13382383e+00 1.10697508e+03 2.69410699e+02 ... 2.01841814e+01
#   4.89013982e+01 1.11131826e+00]
#  [2.13382382e+00 1.10697508e+03 2.69410699e+02 ... 2.01841816e+01
#   4.89013980e+01 1.11131827e+00]
#  [2.13382381e+00 1.10697507e+03 2.69410699e+02 ... 2.01841819e+01
#   4.89013978e+01 1.11131829e+00]]
# C:\Users\Dell\Anaconda3\lib\site-packages\statsmodels\base\wrapper.py:35: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
